# %%
#Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("/content/synthetic_ecommerce_orders_raw.csv")

# %%
data.head(11)
# Out:
#     order_id  customer_id  order_date   age  gender city_tier signup_channel  \
# 0     500000        10117  2025-07-10  29.0  Female    Tier-1       REFERRAL
# 1     500001        10339  2025-11-17  36.0    Male    Tier-1        Partner
# 2     500002        10388  2025-08-15  18.0    Male    Tier-3        Partner
# 3     500003        10192  2025-07-30  49.0    Male    Tier-1        Organic
# 4     500004        10398  2025-10-02  24.0  Female    Tier-1        Organic
# 5     500005        10345  2025-08-01  30.0  Female    Tier-3           Paid
# 6     500006        10194  2025-08-16  18.0  Female    Tier-2           Paid
# 7     500007        10167  2025-09-26  35.0    Male    Tier-3           Paid
# 8     500008        10376  2025-09-01  20.0    Male    Tier-1       Referral
# 9     500009        10238  2025-12-01  31.0    Male    Tier-2        Organic
# 10    500010        10361  2025-11-08  25.0  Female    Tier-1        Organic
#
#    device_type     category payment_method  order_value  discount_pct  \
# 0          iOS      Grocery            COD        30.65          16.4
# 1      Android      Fashion            COD        34.20          30.6
# 2          Web      Fashion            UPI        40.74          28.7
# 3          iOS       Beauty         Wallet        49.63          22.4
# 4      Android      Grocery     NetBanking        63.63           9.0
# 5          Web       Sports           Card        39.95          27.7
# 6          iOS  Electronics            COD        44.62          25.0
# 7      Android      beauty             UPI        28.39          26.0
# 8          iOS         Home            COD       134.36          23.3
# 9      Android         Home            UPI        92.68          17.8
# 10         Web       Sports            COD        66.76          18.5
#
#     shipping_days delivery_status  rating  return_flag  support_tickets  \
# 0             4.0       Delivered     5.0            0              0.0
# 1             4.0       Delivered     3.0            0              0.0
# 2             5.0       Delivered     5.0            0              0.0
# 3             3.0       Delivered     4.0            0              0.0
# 4             3.0       Delivered     5.0            0              0.0
# 5             5.0       Delivered     5.0            0              0.0
# 6             5.0       Delivered     3.0            0              0.0
# 7             5.0       Delivered     5.0            0              1.0
# 8             4.0       Delivered     4.0            0              0.0
# 9             6.0       Delivered     4.0            0              0.0
# 10            4.0       Delivered     4.0            1              0.0
#
#     session_duration_min
# 0                   21.3
# 1                   19.0
# 2                   16.1
# 3                   10.5
# 4                   12.4
# 5                   20.0
# 6                   17.2
# 7                   13.8
# 8                   13.6
# 9                   17.0
# 10                  16.2

# %%
data.tail()
# Out:
#       order_id  customer_id  order_date   age  gender city_tier  \
# 2015    501747        10200  2025-07-11  24.0  Female    Tier-2
# 2016    501696        10250  2025-08-19  45.0  Female    Tier-3
# 2017    500311        10217  2025-12-23  52.0  Female    Tier-3
# 2018    500784        10111  2025-12-07   NaN  Female    Tier-3
# 2019    500646        10331  2025-12-24  22.0    Male    Tier-3
#
#      signup_channel device_type       category payment_method  order_value  \
# 2015        Partner         Web   electronics            card        49.79
# 2016           Paid     Android        Grocery            upi        16.67
# 2017        Partner         iOS        Fashion            upi        11.75
# 2018           Paid         Web           Home     netbanking        47.59
# 2019       Referral         Web         Sports           card        26.04
#
#       discount_pct  shipping_days delivery_status  rating  return_flag  \
# 2015          17.1            6.0       Delivered     4.0            1
# 2016          19.2            5.0       Delivered     4.0            0
# 2017          27.5            5.0       Delivered     4.0            0
# 2018          28.8            5.0       Delivered     5.0            0
# 2019          22.1            5.0       Delivered     5.0            0
#
#       support_tickets  session_duration_min
# 2015              0.0                  18.3
# 2016              0.0                  17.5
# 2017              0.0                  17.9
# 2018              0.0                  18.1
# 2019              1.0                  16.2

# %%
data.shape
# Out:
# (2020, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              2020 non-null   int64
#  1   customer_id           2020 non-null   int64
#  2   order_date            2020 non-null   object
#  3   age                   1951 non-null   float64
#  4   gender                2020 non-null   object
#  5   city_tier             2020 non-null   object
#  6   signup_channel        2020 non-null   object
#  7   device_type           2020 non-null   object
#  8   category              2020 non-null   object
#  9   payment_method        2020 non-null   object
#  10  order_value           2020 non-null   float64
#  11  discount_pct          1975 non-null   float64
#  12  shipping_days         1975 non-null   float64
#  13  delivery_status       2020 non-null   object
#  14  rating                1994 non-null   float64
#  15  return_flag           2020 non-null   int64
#  16  support_tickets       2020 non-null   float64
#  17  session_duration_min  2020 non-null   float64
# dtypes: float64(7), int64(3), object(8)
# memory usage: 284.2+ KB

# %%
data.dtypes
# Out:
# order_id                  int64
# customer_id               int64
# order_date               object
# age                     float64
# gender                   object
# city_tier                object
# signup_channel           object
# device_type              object
# category                 object
# payment_method           object
# order_value             float64
# discount_pct            float64
# shipping_days           float64
# delivery_status          object
# rating                  float64
# return_flag               int64
# support_tickets         float64
# session_duration_min    float64
# dtype: object

# %%
data.describe()
# Out:
#             order_id   customer_id          age  order_value  discount_pct  \
# count    2020.000000   2020.000000  1951.000000  2020.000000   1975.000000
# mean   500999.421287  10197.059406    30.282419    50.712688     20.914430
# std       578.079557    116.553743     7.658660    42.225425      5.963624
# min    500000.000000  10000.000000    18.000000  -108.380000      1.000000
# 25%    500498.750000  10096.000000    25.000000    26.947500     17.100000
# 50%    500998.500000  10197.000000    30.000000    40.140000     20.900000
# 75%    501501.250000  10299.000000    35.000000    60.497500     24.900000
# max    501999.000000  10399.000000    56.000000   455.010000     41.500000
#
#        shipping_days       rating  return_flag  support_tickets  \
# count    1975.000000  1994.000000  2020.000000      2020.000000
# mean        4.814684     3.959880     0.097030         0.337129
# std         1.183339     0.846702     0.296072         0.641713
# min         3.000000     1.000000     0.000000         0.000000
# 25%         4.000000     3.000000     0.000000         0.000000
# 50%         5.000000     4.000000     0.000000         0.000000
# 75%         6.000000     5.000000     0.000000         1.000000
# max        13.000000     5.000000     1.000000         5.000000
#
#        session_duration_min
# count           2020.000000
# mean              16.019356
# std                3.559457
# min                0.000000
# 25%               13.700000
# 50%               16.100000
# 75%               18.500000
# max               27.700000

# %%
missing=data.isna().sum()
print(missing)
# Out:
# order_id                 0
# customer_id              0
# order_date               0
# age                     69
# gender                   0
# city_tier                0
# signup_channel           0
# device_type              0
# category                 0
# payment_method           0
# order_value              0
# discount_pct            45
# shipping_days           45
# delivery_status          0
# rating                  26
# return_flag              0
# support_tickets          0
# session_duration_min     0
# dtype: int64

# %%
missingsort=data.isna().sum().sort_values(ascending=False)
print(missingsort)
# Out:
# age                     69
# discount_pct            45
# shipping_days           45
# rating                  26
# customer_id              0
# order_id                 0
# signup_channel           0
# order_date               0
# gender                   0
# city_tier                0
# payment_method           0
# category                 0
# device_type              0
# order_value              0
# delivery_status          0
# return_flag              0
# support_tickets          0
# session_duration_min     0
# dtype: int64

# %%
duplicates=data.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
missing_treated=(data.isna().mean()*100).sort_values(ascending=False)
print(missing_treated)
# Out:
# age                     3.415842
# discount_pct            2.227723
# shipping_days           2.227723
# rating                  1.287129
# customer_id             0.000000
# order_id                0.000000
# signup_channel          0.000000
# order_date              0.000000
# gender                  0.000000
# city_tier               0.000000
# payment_method          0.000000
# category                0.000000
# device_type             0.000000
# order_value             0.000000
# delivery_status         0.000000
# return_flag             0.000000
# support_tickets         0.000000
# session_duration_min    0.000000
# dtype: float64

# %%
plt.figure()
missing_treated.plot(kind="bar")
plt.title("Missing values")
plt.show()

# %%
cat_cols=['category','signup_channel','payment_method','device_type','city_tier','gender','delivery_status']

# %%
data[cat_cols]
# Out:
#            category signup_channel payment_method device_type city_tier  \
# 0           Grocery       REFERRAL            COD         iOS    Tier-1
# 1           Fashion        Partner            COD     Android    Tier-1
# 2           Fashion        Partner            UPI         Web    Tier-3
# 3            Beauty        Organic         Wallet         iOS    Tier-1
# 4           Grocery        Organic     NetBanking     Android    Tier-1
# ...             ...            ...            ...         ...       ...
# 2015   electronics         Partner           card         Web    Tier-2
# 2016        Grocery           Paid            upi     Android    Tier-3
# 2017        Fashion        Partner            upi         iOS    Tier-3
# 2018           Home           Paid     netbanking         Web    Tier-3
# 2019         Sports       Referral           card         Web    Tier-3
#
#       gender delivery_status
# 0     Female       Delivered
# 1       Male       Delivered
# 2       Male       Delivered
# 3       Male       Delivered
# 4     Female       Delivered
# ...      ...             ...
# 2015  Female       Delivered
# 2016  Female       Delivered
# 2017  Female       Delivered
# 2018  Female       Delivered
# 2019    Male       Delivered
#
# [2020 rows x 7 columns]

# %%
data["category"]=data["category"].str.title()
data["category"]
# Out:
# 0             Grocery
# 1             Fashion
# 2             Fashion
# 3              Beauty
# 4             Grocery
#             ...
# 2015     Electronics
# 2016          Grocery
# 2017          Fashion
# 2018             Home
# 2019           Sports
# Name: category, Length: 2020, dtype: object

# %%
for col in cat_cols:
  data[col]=data[col].str.strip()
data[cat_cols]
# Out:
#          category signup_channel payment_method device_type city_tier  gender  \
# 0         Grocery       REFERRAL            COD         iOS    Tier-1  Female
# 1         Fashion        Partner            COD     Android    Tier-1    Male
# 2         Fashion        Partner            UPI         Web    Tier-3    Male
# 3          Beauty        Organic         Wallet         iOS    Tier-1    Male
# 4         Grocery        Organic     NetBanking     Android    Tier-1  Female
# ...           ...            ...            ...         ...       ...     ...
# 2015  Electronics        Partner           card         Web    Tier-2  Female
# 2016      Grocery           Paid            upi     Android    Tier-3  Female
# 2017      Fashion        Partner            upi         iOS    Tier-3  Female
# 2018         Home           Paid     netbanking         Web    Tier-3  Female
# 2019       Sports       Referral           card         Web    Tier-3    Male
#
#      delivery_status
# 0          Delivered
# 1          Delivered
# 2          Delivered
# 3          Delivered
# 4          Delivered
# ...              ...
# 2015       Delivered
# 2016       Delivered
# 2017       Delivered
# 2018       Delivered
# 2019       Delivered
#
# [2020 rows x 7 columns]

# %%
data.head()
# Out:
#    order_id  customer_id  order_date   age  gender city_tier signup_channel  \
# 0    500000        10117  2025-07-10  29.0  Female    Tier-1       REFERRAL
# 1    500001        10339  2025-11-17  36.0    Male    Tier-1        Partner
# 2    500002        10388  2025-08-15  18.0    Male    Tier-3        Partner
# 3    500003        10192  2025-07-30  49.0    Male    Tier-1        Organic
# 4    500004        10398  2025-10-02  24.0  Female    Tier-1        Organic
#
#   device_type category payment_method  order_value  discount_pct  \
# 0         iOS  Grocery            COD        30.65          16.4
# 1     Android  Fashion            COD        34.20          30.6
# 2         Web  Fashion            UPI        40.74          28.7
# 3         iOS   Beauty         Wallet        49.63          22.4
# 4     Android  Grocery     NetBanking        63.63           9.0
#
#    shipping_days delivery_status  rating  return_flag  support_tickets  \
# 0            4.0       Delivered     5.0            0              0.0
# 1            4.0       Delivered     3.0            0              0.0
# 2            5.0       Delivered     5.0            0              0.0
# 3            3.0       Delivered     4.0            0              0.0
# 4            3.0       Delivered     5.0            0              0.0
#
#    session_duration_min
# 0                  21.3
# 1                  19.0
# 2                  16.1
# 3                  10.5
# 4                  12.4

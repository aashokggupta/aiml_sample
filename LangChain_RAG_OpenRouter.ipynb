# %% [markdown]
# ## LangChain Basics – From LLM Calls to RAG
#
# ### 🎯 Why This Notebook?
#
# Before we jump into the deeper waters of **RAG pipelines** and **Agents**, this notebook will help you warm up with the essential building blocks of LangChain.
#
# You’ll go from:
# <br>
# 🔹 Making a basic **LLM call**
# <br>
# 🔹 Using a **prompt template**
# <br>
# 🔹 Creating **chains** by combining components
# <br>
# 🔹 And finally, building a working **RAG pipeline** : where the LLM answers questions from real documents (not its training data)
#
# This is your playground to build **intuition** before we dive deeper in the live session.
#
# ---
#
# ### 🧠 Core Concepts at a Glance
#
# #### 🔹 LLM Call
# A direct call to an LLM like GPT-4. You give it a prompt, and it gives you an answer. It’s like talking to ChatGPT behind the scenes.
#
# <br>
#
# #### 🔹 Prompt Template
# A reusable way to structure inputs. You can insert variables like `{input}` or `{context}` dynamically — great for consistency and modularity.
#
# <br>
#
# #### 🔹 Chain
# LangChain allows you to connect components together. For example, a **Prompt** → **LLM** → **Output Parser** can be combined into a single "chain" that flows from input to output.
#
# <br>
#
# #### 🔹 RAG (Retrieval-Augmented Generation)
# Instead of relying only on the LLM’s memory, RAG lets us bring in **external knowledge**.
#
# It works like this:
# - A **retriever** pulls relevant document chunks from a vector database
# - These are inserted into a prompt template as **context**
# - The **LLM** is then asked to answer based only on that context
#
# This is powerful for use cases like:
# - Chatbots over documentation
# - Q&A on company wikis or PDFs
# - Smart search assistants
#
# ---

# %% [markdown]
# ### Installing Packages

# %%
# !pip install langchain langchain-core langchain-community langchain_openai faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.3.6)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (1.4.3)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-1.3.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.14.3-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.5.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.8.12)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.14.1)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.50)
# Collecting langchain-core
#   Downloading langchain_core-1.4.7-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (2.41.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.13.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.10.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.18.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain) (3.7.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.5.20)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain) (1.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.2)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 20.1 MB/s eta 0:00:00
# Downloading langchain_openai-1.3.2-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 6.6 MB/s eta 0:00:00
# Downloading langchain_core-1.4.7-py3-none-any.whl (554 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 25.3 MB/s eta 0:00:00
# Downloading faiss_cpu-1.14.3-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 43.7 MB/s eta 0:00:00
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.1 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, faiss-cpu, langchain-core, langchain-text-splitters, langchain_openai, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.3
#     Uninstalling langchain-core-1.4.3:
#       Successfully uninstalled langchain-core-1.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed faiss-cpu-1.14.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-core-1.4.7 langchain-text-splitters-1.1.2 langchain_openai-1.3.2 requests-2.34.2

# %% [markdown]
# ### Setting Up API Access

# %%
import os
import getpass

os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter OpenRouter API Key: ")
# Out:
# Enter OpenRouter API Key: ··········

# %% [markdown]
# #### Code Explanation:
#
# `getpass.getpass()` safely asks for your OpenAI API key without showing it on the screen.
#
# `LANGCHAIN_TRACING_V2 = "true"` turns on a useful tracking tool that helps you see what your LangChain app is doing step-by-step. Super helpful for debugging or understanding how the pieces work together.
# Think of it like switching on a "behind-the-scenes" camera for your LLM workflows.

# %%
# OpenRouter LLM
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0,
    openai_api_key=os.environ["OPENROUTER_API_KEY"],
    base_url="https://openrouter.ai/api/v1"
)

# %% [markdown]
# ### Simple LLM Call

# %%
answer = llm.invoke("what is your cuttoff date")
print(answer.content)
# Out:
# My knowledge is based on information available up until October 2021. If you have questions or need information up to that date, feel free to ask!

# %% [markdown]
# ### Explanation:
#
# `ChatOpenAI` is LangChain’s wrapper around OpenAI’s chat models (like GPT-3.5 or GPT-4).
#
# We’re creating an LLM instance (llm) that’s ready to receive prompts and return responses.
#
# The api_key is securely pulled from your environment (as set earlier), so you don’t have to hardcode secrets.

# %% [markdown]
# * You’re sending a prompt directly to the LLM using `.invoke()`.
#
# * The response is returned as a ChatMessage object — it contains both the content and metadata.
#
# Think of this as a raw "ask-and-answer" interaction with the model.

# %%
# Print the LLM's response to the prompt
print(answer)

# Print the type of the response object (useful for understanding the structure of the output)
print(type(answer))
# Out:
# content="Google serves a variety of purposes and offers numerous services that cater to different needs. Here are some of the primary uses of Google:\n\n1. **Search Engine**: Google is best known for its search engine, which allows users to find information on the internet by entering keywords or phrases. It provides links to websites, images, videos, news articles, and more.\n\n2. **Email Services**: Gmail is Google's email service, offering users a platform to send and receive emails, manage contacts, and organize messages with features like labels and filters.\n\n3. **Cloud Storage**: Google Drive provides cloud storage solutions, allowing users to store files online, share documents, and collaborate in real-time using Google Docs, Sheets, and Slides.\n\n4. **Maps and Navigation**: Google Maps offers detailed maps, satellite imagery, and navigation services, helping users find directions, explore locations, and discover local businesses.\n\n5. **Advertising**: Google Ads is a platform for businesses to create online advertisements that appear in search results and on websites, helping them reach potential customers.\n\n6. **Video Sharing**: YouTube, owned by Google, is a popular platform for sharing and watching videos, ranging from user-generated content to professional productions.\n\n7. **Mobile Operating System**: Android, developed by Google, is a widely used mobile operating system for smartphones and tablets.\n\n8. **Web Browsing**: Google Chrome is a web browser that allows users to access the internet, with features like extensions, bookmarks, and synchronization across devices.\n\n9. **Productivity Tools**: Google Workspace (formerly G Suite) includes tools like Google Calendar, Google Meet, and Google Keep, which help individuals and teams manage their schedules, conduct meetings, and take notes.\n\n10. **Artificial Intelligence**: Google develops AI technologies and services, including Google Assistant, which provides voice-activated assistance for various tasks.\n\n11. **Research and Development**: Google invests in various research initiatives and projects, including advancements in machine learning, quantum computing, and autonomous vehicles.\n\nOverall, Google is a multifaceted platform that plays a significant role in how people access information, communicate, and utilize technology in their daily lives." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 438, 'prompt_tokens': 14, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.0002649, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.0002649, 'upstream_inference_prompt_cost': 2.1e-06, 'upstream_inference_completions_cost': 0.0002628}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_4dcfea0a44', 'id': 'gen-1780839543-ujJ11lrwTF6ezx0rp1xy', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ea24e-f0e1-7a52-99a9-ca33739deca2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 14, 'output_tokens': 438, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.ai.AIMessage'>

# %% [markdown]
# The above prints the full response object and its type; usually a AIMessage from LangChain.

# %%
# Print just the textual content of the LLM's response (excluding metadata or other attributes)
print(answer.content)
# Out:
# Google serves a variety of purposes and offers numerous services that cater to different needs. Here are some of the primary uses of Google:
#
# 1. **Search Engine**: Google is best known for its search engine, which allows users to find information on the internet by entering keywords or phrases. It provides links to websites, images, videos, news articles, and more.
#
# 2. **Email Services**: Gmail is Google's email service, offering users a platform to send and receive emails, manage contacts, and organize messages with features like labels and filters.
#
# 3. **Cloud Storage**: Google Drive provides cloud storage solutions, allowing users to store files online, share documents, and collaborate in real-time using Google Docs, Sheets, and Slides.
#
# 4. **Maps and Navigation**: Google Maps offers detailed maps, satellite imagery, and navigation services, helping users find directions, explore locations, and discover local businesses.
#
# 5. **Advertising**: Google Ads is a platform for businesses to create online advertisements that appear in search results and on websites, helping them reach potential customers.
#
# 6. **Video Sharing**: YouTube, owned by Google, is a popular platform for sharing and watching videos, ranging from user-generated content to professional productions.
#
# 7. **Mobile Operating System**: Android, developed by Google, is a widely used mobile operating system for smartphones and tablets.
#
# 8. **Web Browsing**: Google Chrome is a web browser that allows users to access the internet, with features like extensions, bookmarks, and synchronization across devices.
#
# 9. **Productivity Tools**: Google Workspace (formerly G Suite) includes tools like Google Calendar, Google Meet, and Google Keep, which help individuals and teams manage their schedules, conduct meetings, and take notes.
#
# 10. **Artificial Intelligence**: Google develops AI technologies and services, including Google Assistant, which provides voice-activated assistance for various tasks.
#
# 11. **Research and Development**: Google invests in various research initiatives and projects, including advancements in machine learning, quantum computing, and autonomous vehicles.
#
# Overall, Google is a multifaceted platform that plays a significant role in how people access information, communicate, and utilize technology in their daily lives.

# %% [markdown]
# ### Output (summarized):
# The LLM gives a generic explanation of how a company named "Langsmith" could help with language testing, listing use cases like test platforms, scoring, and prep materials.
#
# ### Why This Isn’t Enough
# The response is factual but generic — there’s no control, formatting, or customization.
# This is why we move on to **Prompt Templates** and **Chaining** to make the outputs richer, structured, and more task-specific.

# %% [markdown]
# ### Using a Prompt Template

# %%
# Import ChatPromptTemplate to structure multi-turn conversational prompts
from langchain_core.prompts import ChatPromptTemplate

# Define a prompt template with system, human, and AI message roles
template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI bot. Your name is {name}."),
    ("human", "Hello, how are you doing?"),
    ("ai", "I'm doing well, thanks!"),
    ("human", "{user_input}"),
])

# Populate the template with actual variables
prompt_value = template.invoke(
    {
        "name": "Bob",
        "user_input": "What is your name?"
    }
)

# %% [markdown]
# ### Code Explanation:
#
# * `ChatPromptTemplate` lets you define a structured multi-turn conversation format using roles: system, human, ai.
#
# * Variables like `{name}` and `{user_input}` are placeholders you can fill in dynamically.
#
# * `template.invoke(...)` injects values into the template. Here, name = "Bob" and the user asks a follow-up question.
#
# This helps simulate real conversational context and control how the model is prompted.

# %%
# Iterate over the messages in the generated prompt and print the type of each message.
for msg in prompt_value.messages:
  print(type(msg).__name__, ":", msg.content)
# Out:
# SystemMessage : You are a helpful AI bot. Your name is Bob.
# HumanMessage : Hello, how are you doing?
# AIMessage : I'm doing well, thanks!
# HumanMessage : What is your name?

# %% [markdown]
#  The above block prints each message in the constructed prompt, showing how the roles (system, human, ai) and variables came together to form a complete, conversational input to the LLM.
# Useful for debugging and understanding exactly what the LLM will "see".

# %%
# Import ChatPromptTemplate to define structured chat prompts
from langchain_core.prompts import ChatPromptTemplate

# Create a prompt template with a system message and a placeholder for user input
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world class technical documentation writer. Respond in that manner only."), # system instructions
    ("user", "{input}")
])

# %%
for msg in prompt.messages:
  print(type(msg).__name__, ":", msg)
# Out:
# SystemMessagePromptTemplate : prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a world class technical documentation writer. Respond in that manner only.') additional_kwargs={}
# HumanMessagePromptTemplate : prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}') additional_kwargs={}

# %% [markdown]
# Similarly, the above two blocks sets up a prompt template — this time with a single-turn interaction focused on technical documentation.

# %% [markdown]
# ### Creating a Simple Chain

# %%
# Create a simple chain by piping the prompt into the LLM
chain = prompt | llm

# %% [markdown]
# ### Explanation:
#
# * This creates a chain by connecting the `prompt` directly to the `llm` using the `|` operator.
#
# * When invoked, the prompt gets formatted with user input and immediately passed to the LLM.
#
# This modular approach lets you build pipelines that are easy to extend and reuse.

# %%
# Print the first component of the chain (useful for inspecting the pipeline's starting point)
print(chain)
# Out:
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a world class technical documentation writer. Respond in that manner only.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[] last=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x7a6375b81f70>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7a6375707da0>, root_client=<openai.OpenAI object at 0x7a6376e48380>, root_async_client=<openai.AsyncOpenAI object at 0x7a637587c1d0>, model_name='openai/gpt-4o-mini', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://openrouter.ai/api/v1', stream_chunk_timeout=120.0)

# %% [markdown]
# The above shows the first component in the chain — in this case, it’s the full prompt template with structure and placeholders (`{input}`) clearly laid out. Useful for inspecting how your chain starts.

# %% [markdown]
# ### Running the Chain with Input

# %%
# Invoke the full chain with user input; the prompt is formatted and passed to the LLM
chain_result = chain.invoke({"input": "how can h2o help with testing?"})

# %% [markdown]
# #### Explanation:
#
# * This passes a user question into the chain.
#
# * The `{input}` placeholder in the prompt is filled with the actual query.
#
# * The prompt is sent to the LLM, and the final response is stored in `chain_result`.

# %%
print(chain_result.content) # Print the content of the response generated by the chain
# Out:
# H2O is an open-source software for data analysis that provides a suite of tools and functionalities that can significantly enhance the testing process, particularly in the context of machine learning and data-driven applications. Below are several ways H2O can assist with testing:
#
# ### 1. **Automated Model Testing**
#    - **Cross-Validation**: H2O supports k-fold cross-validation, allowing users to assess the performance of machine learning models on different subsets of data. This helps in understanding model stability and generalization.
#    - **Grid Search**: H2O facilitates hyperparameter tuning through grid search, enabling the systematic testing of various model configurations to identify the optimal settings.
#
# ### 2. **Performance Metrics**
#    - H2O provides a comprehensive set of performance metrics (e.g., accuracy, precision, recall, F1 score, AUC) that can be used to evaluate model performance. This allows for rigorous testing of model efficacy against predefined benchmarks.
#
# ### 3. **Data Validation**
#    - **Data Quality Checks**: H2O can be used to perform data validation checks, ensuring that the input data meets quality standards before model training and testing. This includes checking for missing values, outliers, and data distribution.
#
# ### 4. **Integration with Testing Frameworks**
#    - H2O can be integrated with popular testing frameworks (e.g., pytest, unittest) in Python, allowing for the automation of testing workflows. This integration can facilitate the creation of unit tests for model training and evaluation functions.
#
# ### 5. **Model Interpretability**
#    - H2O provides tools for model interpretability, such as variable importance plots and SHAP (SHapley Additive exPlanations) values. These tools can be used to test and validate the reasoning behind model predictions, ensuring that models are not only accurate but also interpretable.
#
# ### 6. **Scalability and Performance Testing**
#    - H2O is designed to handle large datasets efficiently. It allows for performance testing under various load conditions, ensuring that models can scale and perform well in production environments.
#
# ### 7. **Deployment Testing**
#    - H2O supports model deployment through H2O's MOJO (Model Object, Optimized) format, which can be tested in production-like environments to ensure that the model behaves as expected when integrated into applications.
#
# ### Conclusion
# By leveraging H2O's capabilities, teams can enhance their testing processes, ensuring that machine learning models are robust, reliable, and ready for deployment. The combination of automated testing, performance evaluation, and integration with existing workflows makes H2O a valuable tool in the testing landscape.

# %% [markdown]
# The above prints just the final response text from the chain.
# Compared to the earlier raw LLM call, this output is better structured and more task-specific. Thanks to the prompt that positioned the LLM as a technical documentation writer.

# %%
print(chain_result.response_metadata) # Print metadata about the LLM's response (e.g., token usage, model info, etc.)
# Out:
# {'token_usage': {'completion_tokens': 536, 'prompt_tokens': 35, 'total_tokens': 571, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.00032685, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.00032685, 'upstream_inference_prompt_cost': 5.25e-06, 'upstream_inference_completions_cost': 0.0003216}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_4dcfea0a44', 'id': 'gen-1780839549-dATzE3eGRldRrXakgy4F', 'finish_reason': 'stop', 'logprobs': None}

# %% [markdown]
# The above displays metadata about the LLM call — including token usage, model name, and finish reason.
# Useful for monitoring cost, performance, and debugging.

# %% [markdown]
# ### Cleaning Output with an Output Parser

# %%
# Import a parser that extracts plain string content from LLM responses
from langchain_core.output_parsers import StrOutputParser

# Initialize the string output parser
output_parser = StrOutputParser()

# %%
# Create a full chain that formats the prompt, sends it to the LLM, and parses the output into a plain string
chain = prompt | llm | output_parser

# %% [markdown]
# * `StrOutputParser()` is added at the end of the chain to cleanly extract just the string/text output from the LLM's response.
#
# * Without this, you'd get a full object (`AIMessage`). With this, you directly get plain text — easy to print, log, or pass to other tools

# %%
# Invoke the updated chain with user input; returns the final parsed string response
chain_result = chain.invoke({"input": "how can langsmith help with testing?"})

# %%
print(chain_result) #print the final plain-text result returned by the chain
# Out:
# LangSmith is a powerful tool designed to enhance the testing process for applications that utilize natural language processing (NLP) and machine learning models. Below are several ways in which LangSmith can assist with testing:
#
# ### 1. **Automated Test Generation**
#    - **Input Variability**: LangSmith can generate a wide range of input variations to test the robustness of NLP models. This includes paraphrasing, synonym replacement, and other linguistic transformations.
#    - **Edge Case Identification**: The tool can help identify edge cases that may not be covered by standard test cases, ensuring comprehensive testing.
#
# ### 2. **Test Case Management**
#    - **Organized Test Suites**: LangSmith allows users to create and manage organized test suites, making it easier to track which tests have been executed and their outcomes.
#    - **Version Control**: It supports versioning of test cases, enabling teams to maintain historical records and revert to previous versions if necessary.
#
# ### 3. **Performance Evaluation**
#    - **Metrics Tracking**: LangSmith can track various performance metrics, such as accuracy, precision, recall, and F1 score, providing insights into model performance over time.
#    - **Benchmarking**: The tool can facilitate benchmarking against industry standards or previous model versions, helping teams assess improvements or regressions.
#
# ### 4. **Integration with CI/CD Pipelines**
#    - **Seamless Integration**: LangSmith can be integrated into continuous integration and continuous deployment (CI/CD) pipelines, allowing for automated testing as part of the development workflow.
#    - **Real-time Feedback**: Developers receive immediate feedback on model performance after each deployment, enabling rapid iteration and improvement.
#
# ### 5. **User Feedback Incorporation**
#    - **Feedback Loop**: LangSmith can incorporate user feedback into the testing process, allowing for the adjustment of test cases based on real-world usage and performance.
#    - **A/B Testing Support**: The tool can facilitate A/B testing scenarios to compare different model versions or configurations based on user interactions.
#
# ### 6. **Documentation and Reporting**
#    - **Comprehensive Reporting**: LangSmith generates detailed reports on test results, including pass/fail rates, error analysis, and suggestions for improvement.
#    - **Documentation Generation**: The tool can automatically generate documentation for test cases, making it easier for teams to understand the testing process and results.
#
# ### Conclusion
# By leveraging LangSmith, teams can enhance their testing strategies for NLP applications, ensuring higher quality, reliability, and performance of their models. The tool's capabilities in automated test generation, performance evaluation, and integration with development workflows make it an invaluable asset in the testing landscape.

# %% [markdown]
# ### Output Summary
# The response is now a well-structured, markdown-friendly explanation of how Langsmith can help in testing, with bold headings and bullet points.
#
# Compared to earlier:
#
# * The content quality is preserved, but
#
# * The format is simplified — no wrappers, metadata, or .content access needed.
#
# * Final result: Clean, ready-to-display text, great for UI responses, logging, or piping into downstream logic.
# <br>

# %% [markdown]
# #### Now we're entering the RAG (Retrieval-Augmented Generation) part of the pipeline.

# %% [markdown]
# ### Loading External Documents

# %%
# Import a loader to fetch and parse web page content
from langchain_community.document_loaders import WebBaseLoader

# Initialize the web loader with the URL of the LangSmith documentation
loader = WebBaseLoader("https://docs.smith.langchain.com/")

# Load the content from the webpage into a list of Document objects
docs = loader.load()
# Out:
# /tmp/ipykernel_2159/3225703843.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ### Explanation :
#
# * We use `WebBaseLoader` to scrape and load content from a webpage — in this case, LangSmith’s official documentation.
#
# * The output, `docs`, is a list of `Document` objects containing text content and metadata.
#
# This forms the knowledge source that RAG will later retrieve from.

# %%
docs
# Out:
# [Document(metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainDocumentation IndexFetch the complete documentation index at: /llms.txtUse this file to discover all available pages before exploring further.Skip to main contentDocs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyProfile configurationIntegrationsPlansEnterprise featuresLLM GatewayPrivate betaOverviewSpend policiesPII and secrets redactionAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIAudit logsToolsChatCLISkillsSandboxesAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate outputs, test prompts, and manage deployments all in one place, with your agent stack.\n\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:\nObservabilityGain visibility into every step your application takes to debug faster and improve reliability.Start tracingEvaluationMeasure and track quality over time to ensure your AI applications are consistent and trustworthy.Evaluate your appDeploymentDeploy your agents as Agent Servers, ready to scale in production.Deploy your agents\n\u200bMore ways to build\nFleetDesign and deploy AI agents visually without writing code.Build an agentPrompt engineeringIterate on prompts with built-in versioning and collaboration to ship improvements faster.Test your promptsLangSmith CLIQuery and manage traces, datasets, experiments, and more from the terminal.Use the CLIStudioUse a visual interface to design, test, and refine applications end-to-end.Develop with Studio\n\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center\n\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.\n\n\n\nConnect these docs to Claude, VSCode, and more via MCP for real-time answers.Edit this page on GitHub or file an issue.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyContact SalesCompanyHomeTrust CenterCareersBloggithubxlinkedinyoutube\n')]

# %% [markdown]
# ###  Creating Embeddings

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# /tmp/ipykernel_2159/3055314890.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Explanation:
#
# * This sets up an **embedding** model using OpenAI which will convert document chunks into numerical vectors.
#
# * These **embeddings** allow us to search for similar content during retrieval (based on user queries).
#
# Think of it as setting up the brain that knows how to compare and find "close meaning" between texts.

# %% [markdown]
# ### Splitting Text & Creating a Vector Store

# %%
# Import FAISS for vector storage and similarity search
from langchain_community.vectorstores import FAISS

# Import a text splitter that recursively splits documents into manageable chunks
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Initialize the recursive text splitter (uses default chunk size and overlap)
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)

# Split the loaded documents into smaller chunks suitable for embedding
chunks = text_splitter.split_documents(docs)

# Create a FAISS vector store from the document chunks using the specified embeddings
vector = FAISS.from_documents(chunks, embeddings)

# %% [markdown]
# ### Explanation:
#
# * `RecursiveCharacterTextSplitter` breaks long documents into smaller, overlapping chunks which makes them easier to retrieve and keeps context tight.
#
# * These chunks are then converted into embeddings and stored in a** FAISS vector store**, a high-performance similarity search index.
#
# * `vector` is now your searchable knowledge base. You can ask it questions, and it will return the most relevant chunks.

# %% [markdown]
# ### Creating a Document-Answering Chain (Stuff Method)

# %%
# !pip install langchain-classic
# Out:
# Requirement already satisfied: langchain-classic in /usr/local/lib/python3.12/dist-packages (1.0.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (1.4.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (1.1.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (0.8.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.0.50)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.3->langchain-classic) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.3->langchain-classic) (0.0.16)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.3->langchain-classic) (26.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.3->langchain-classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.3->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.3->langchain-classic) (0.16.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2026.5.20)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain-classic) (3.1.1)

# %%
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_classic.chains.retrieval import create_retrieval_chain
# create_stuff_documents_chain :
#  Create a chain for passing a list of Documents to a model.

prompt = ChatPromptTemplate.from_template("""
Answer the following question based only on the provided context, If no context answer don't answer:


{context}



Question: {input} """, output_parser = output_parser)

document_chain = create_stuff_documents_chain(llm, prompt) # prompt | llm

# %% [markdown]
# ![Document Chain.png](data:image/png;base64,...)

# %% [markdown]
# ####Explanation:
#
#
# - We're using the `create_stuff_documents_chain()` method, which builds a chain that:
#   - Accepts a list of documents
#   - "Stuffs" them into a prompt under the `<context>` section
#   - Passes the complete prompt to the LLM
#
# - The prompt is carefully structured:
#   - It tells the LLM to **only answer using the provided context**
#   - `{context}` gets replaced with the retrieved documents
#   - `{input}` is the user’s question
#
# - We also attach the `output_parser` to extract a clean text response from the LLM.
#
# This chain is now ready to be combined with a retriever to form a full RAG pipeline.

# %% [markdown]
# ### Creating the Full Retrieval Chain (RAG)

# %% [markdown]
# ### 🖼 RAG in Action:
#
#
# Here's what’s happening in the image:
# - The **Retriever** finds relevant content for the user’s query
# - This content is inserted into a prompt as `<context>`
# - The **LLM** is instructed to answer the `{input}` question based **only** on that context
#
# > In short: the LLM isn't guessing — it's being fed the right context just-in-time.
#
# ---
#
# ✅ With that mental model in place, let's start coding our way from a simple LLM call to a full working RAG chain.

# %% [markdown]
# Below is a simplified visual of what a RAG pipeline looks like:
#
# ![image.png](data:image/png;base64,...)

# %%
# Import a helper function to create a retrieval-augmented generation (RAG) chain


# Convert the vector store into a retriever for performing similarity search
retriever = vector.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={
        "k": 3,
        "score_threshold": 0.2
    }
)

# Create a retrieval chain that uses the retriever and a document-answering chain
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %% [markdown]
# ### Explanation:
#
#
#
# - `vector.as_retriever()` converts the FAISS vector store into a **retriever**, which can search and return relevant document chunks based on a user query.
#
# - `create_retrieval_chain()` then connects:
#   - the **retriever** (to fetch relevant context),
#   - and the **document chain** (to pass that context + question to the LLM).
#
# Together, this forms a complete **Retrieval-Augmented Generation (RAG)** pipeline.
#
# Now when you invoke this chain with a question, it will:
# > 1. Retrieve relevant chunks,
# > 2. Stuff them into a prompt,
# > 3. And get a focused answer from the LLM based only on those documents.

# %%
# Invoke the retrieval chain with a user query; it retrieves relevant documents and generates an answer
response = retrieval_chain.invoke({"input": "who is sachin tendulkar?"})
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/base.py:1048: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='e2e245aa-8d57-4745-a08c-585039f8656a', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainDocumentation IndexFetch the complete documentation index at: /llms.txtUse this file to discover all available pages before exploring further.Skip to main contentDocs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyProfile configurationIntegrationsPlansEnterprise'), np.float32(-0.32294273)), (Document(id='2e29963b-196c-4082-9130-421f48400d48', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center\n\u200bWorkflow'), np.float32(-0.33615792)), (Document(id='1e4b3b48-1ca4-464f-8cc5-e07659049fac', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='configurationIntegrationsPlansEnterprise featuresLLM GatewayPrivate betaOverviewSpend policiesPII and secrets redactionAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIAudit logsToolsChatCLISkillsSandboxesAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate'), np.float32(-0.3562801)), (Document(id='a4ce6556-883d-4f94-bfbf-e5d93e8f8463', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:'), np.float32(-0.36994147)), (Document(id='aaeb4211-b0f8-462f-a754-27bd1a515a22', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'), np.float32(-0.38618946)), (Document(id='37fd01c7-69da-46dc-9783-52449fe108fd', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Edit this page on GitHub or file an issue.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyContact SalesCompanyHomeTrust CenterCareersBloggithubxlinkedinyoutube'), np.float32(-0.38970506)), (Document(id='0a1fcce9-b753-4eb5-9d7d-22393d0cfabe', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': ' ...
#   self.vectorstore.similarity_search_with_relevance_scores(
# WARNING:langchain_core.vectorstores.base:No relevant docs were retrieved using the relevance score threshold 0.2

# %% [markdown]
# This runs the full RAG chain with the question "how can langsmith help with testing?"
# It retrieves relevant chunks from the LangSmith docs, passes them to the LLM, and prints the final answer.

# %%
# Print the final answer generated by the retrieval chain
print(response["answer"])
# Out:
# I'm sorry, but I cannot answer that question as there is no context provided.

# %% [markdown]
# ### Output Summary
# The response is grounded in the actual documentation, highlighting LangSmith’s observability, feedback tools, and evaluation metrics — much more accurate and specific than generic answers earlier.
#
# This shows the power of RAG: the LLM isn't guessing — it's answering based on real, retrieved content.

# %%
# Invoke the retrieval chain with a follow-up question
response = retrieval_chain.invoke({"input": "how can I use langsmith?"})

# Print the generated answer, which should use context from previously retrieved documents
print(response["answer"])
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/base.py:1048: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='e2e245aa-8d57-4745-a08c-585039f8656a', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='LangSmith docs - Docs by LangChainDocumentation IndexFetch the complete documentation index at: /llms.txtUse this file to discover all available pages before exploring further.Skip to main contentDocs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyProfile configurationIntegrationsPlansEnterprise'), np.float32(0.47807395)), (Document(id='a4ce6556-883d-4f94-bfbf-e5d93e8f8463', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bGet started\nCreate an accountSign up at smith.langchain.com (no credit card required).\nYou can log in with Google, GitHub, or email.Create an API keyGo to your Settings page → API Keys → Create API Key.\nCopy the key and save it securely.Choose your integrationLangSmith works with many frameworks and providers. Browse available integrations to connect your stack.\nOnce your account and API key are ready, choose a quickstart to begin building with LangSmith:'), np.float32(0.4235617)), (Document(id='2e29963b-196c-4082-9130-421f48400d48', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bInfrastructure\nPlatform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center\n\u200bWorkflow'), np.float32(0.16642368)), (Document(id='aaeb4211-b0f8-462f-a754-27bd1a515a22', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='\u200bWorkflow\nLangSmith combines observability, evaluation, deployment, and platform setup in one integrated workflow—from local development to production.'), np.float32(0.11507481)), (Document(id='37fd01c7-69da-46dc-9783-52449fe108fd', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Edit this page on GitHub or file an issue.Was this page helpful?YesNoCreate an account and API keyNext⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyContact SalesCompanyHomeTrust CenterCareersBloggithubxlinkedinyoutube'), np.float32(-0.039602876)), (Document(id='1e4b3b48-1ca4-464f-8cc5-e07659049fac', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}, page_content='configurationIntegrationsPlansEnterprise featuresLLM GatewayPrivate betaOverviewSpend policiesPII and secrets redactionAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIAudit logsToolsChatCLISkillsSandboxesAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate'), np.float32(-0.16252732)), (Document(id='7133ff65-49ed-47c2-a023-ef35d452a8fb', metadata={'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en' ...
#   self.vectorstore.similarity_search_with_relevance_scores(
# To use LangSmith, you can follow these steps:
#
# 1. **Create an Account**: Sign up at smith.langchain.com (no credit card required). You can log in using Google, GitHub, or your email.
#
# 2. **Create an API Key**: After logging in, go to your Settings page, navigate to API Keys, and create an API key. Make sure to copy the key and save it securely.
#
# 3. **Choose Your Integration**: LangSmith works with various frameworks and providers. Browse the available integrations to connect your stack.
#
# 4. **Start Building**: Once your account and API key are ready, choose a quickstart to begin building with LangSmith.

# %%
query = "who is sachin tendulkar?"

docs_with_scores = vector.similarity_search_with_score(
    query,
    k=3
)

for i, (doc, score) in enumerate(docs_with_scores, start=1):
    print(f"\n--- Chunk {i} ---")
    print("Score:", score)
    print("Content:")
    print(doc.page_content)
    print("Metadata:")
    print(doc.metadata)
# Out:
# --- Chunk 1 ---
# Score: 1.8709235
# Content:
# LangSmith docs - Docs by LangChainDocumentation IndexFetch the complete documentation index at: /llms.txtUse this file to discover all available pages before exploring further.Skip to main contentDocs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangSmith docsGet startedObservabilityEvaluationPrompt engineeringAgent deploymentPlatform setupReferenceOverviewCreate an account and API keyProfile configurationIntegrationsPlansEnterprise
# Metadata:
# {'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}
#
# --- Chunk 2 ---
# Score: 1.8896126
# Content:
# ​Infrastructure
# Platform setupUse LangSmith in managed cloud, in a self-hosted environment, or hybrid to match your infrastructure and compliance needs.Choose how to set up LangSmithSecurity & complianceLangSmith meets the highest standards of data security and privacy with HIPAA, SOC 2 Type 2, and GDPR compliance. Meet with our team to learn more or visit our Trust Center.Visit Trust Center
# ​Workflow
# Metadata:
# {'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}
#
# --- Chunk 3 ---
# Score: 1.9180697
# Content:
# configurationIntegrationsPlansEnterprise featuresLLM GatewayPrivate betaOverviewSpend policiesPII and secrets redactionAccount administrationOverviewWorkspace setupUsers & access controlBilling & usageManage organizations using the APIAudit logsToolsChatCLISkillsSandboxesAdditional resourcesData & complianceFAQLangSmith statusLangSmith docsCopy pageCopy pageLangSmith is a framework-agnostic platform for building, debugging, and deploying AI agents and LLM applications. Trace requests, evaluate
# Metadata:
# {'source': 'https://docs.smith.langchain.com/', 'title': 'LangSmith docs - Docs by LangChain', 'language': 'en'}

# %% [markdown]
# Even though the question was vague ("How can I use it?"), the RAG setup still returned an accurate answer.
# It understood what “it” referred to (LangSmith) by grounding the response in the retrieved documentation.
#
# This demonstrates a key strength of RAG: the model doesn't have to guess — it uses retrieved context to resolve ambiguity and deliver relevant, specific answers.

# %% [markdown]
# ---
#
# ### 🧪 Try It Yourself: Hands-On Exercises
# You've just built a working RAG pipeline using LangChain — from basic LLM calls all the way to retrieval-augmented answers over real documentation.
#
# Try extending what you've learned with the following hands-on tasks:
#
# ---
#
# ### 1. 🔄 Modify the Prompt Style
# Tweak the system prompt to change the LLM’s behavior. For example:
# - Make it more concise
# - Use a professional or casual tone
# - Format answers as bullet points or numbered steps
#
# 💡 *Tip: Try instructing it to act like a teacher or a product manager.*
#
# ---
#
# ### 2. 🌐 Use a Different Source
# Instead of the LangSmith docs, try building a RAG pipeline over:
# - OpenAI documentation
# - Hugging Face blog
# - Any product’s FAQ page
#
# 🛠 Change the URL inside `WebBaseLoader`.
#
# ---
#
# ### 3. 🤔 Compare: RAG vs Raw LLM
# Run the same question:
# - Once using `llm.invoke(...)`
# - Then using the full `retrieval_chain.invoke(...)`
#
# Notice how the RAG version gives more grounded and specific answers.
#
# ---
#
# ### 4. ✍️ Add Few-shot Examples
# Try adding one or two sample Q&A pairs directly into the prompt template — this helps guide the model toward your desired answer style.
#
# ---
#
# ### 5. 🕵️ Inspect What’s Being Retrieved
# Before the LLM responds, print out the retrieved chunks to see what content it's using.
#
# ```python
# docs = retriever.get_relevant_documents("your question")
# for d in docs:
#     print(d.page_content[:300])

# %% [markdown]
# ---
# ### 6. 💬 Build a Mini Q&A Bot (Bonus)
# Turn your retrieval_chain.invoke() into a simple chatbot loop:

# %%
while True:
    query = input("Ask something: ")
    if query.lower() in ["exit", "quit"]:
        break
    print(retrieval_chain.invoke({"input": query})["answer"])

# %% [markdown]
# 🧠 These exercises will help solidify your grasp on prompting, retrieval, and how to build useful tools on top of LLMs. Give them a shot!
